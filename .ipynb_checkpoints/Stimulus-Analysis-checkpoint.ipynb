# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import pycountry
import pickle
import us

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')


from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer 

from gensim.models import Word2Vec

from textblob import TextBlob

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score

# %matplotlib inline

# %config IPCompleter.greedy=True

pd.set_option('display.max_colwidth', None)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/linhnguyen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/linhnguyen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/linhnguyen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f67c64c7fba6> in <module>
#      19 from nltk.stem import WordNetLemmatizer, PorterStemmer
#      20
# ---> 21 from gensim.models import Word2Vec
#      22
#      23 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'gensim'

# %%
# Take a look at the output
stimulus_raw = pd.read_csv("stimulus_raw.csv")

# Print the first five rows
display(stimulus_raw.head())

# Print the summary statistics
print(stimulus_raw.describe())

# Print the info
print(stimulus_raw.info())
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                              Content          Location  \
# 0  @ZupancicJareen Follow #BidenLies #BidenLied a...               NaN
# 1  Link to get :👇👇👇\nhttps://t.co/kRoIosUS6y\n#Tr...        Etats-Unis
# 2  #Trump 🇺🇸\nWaPo Fact-Checkers Slam #BidenLied ...    Hyères, France
# 3  YouTube doing away with dislikes bc of Whiteho...  Clown World, USA
# 4  Everyone knows this is happening to protect #B...               NaN
#
#           Username  Retweet-Count  Favorites           Created at
# 0    Trish22758076              0          0  2021-03-30 22:59:04
# 1   Hicham21940587              1          0  2021-03-30 22:48:48
# 2           C_W_UK              0          0  2021-03-30 22:47:54
# 3  BEcAMearekonING              0          0  2021-03-30 22:46:12
# 4       BilukCyril              0          0  2021-03-30 22:39:17
#         Unnamed: 0  Unnamed: 0.1  Retweet-Count     Favorites
# count  8084.000000   8084.000000    8084.000000   8084.000000
# mean   4041.500000    716.413409       2.830901     11.922934
# std    2333.794121    435.993453     117.158487    552.269555
# min       0.000000      0.000000       0.000000      0.000000
# 25%    2020.750000    336.000000       0.000000      0.000000
# 50%    4041.500000    691.000000       0.000000      0.000000
# 75%    6062.250000   1095.000000       0.000000      2.000000
# max    8083.000000   1499.000000   10016.000000  47094.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8084 entries, 0 to 8083
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8084 non-null   int64
#  1   Unnamed: 0.1   8084 non-null   int64
#  2   Content        8084 non-null   object
#  3   Location       5682 non-null   object
#  4   Username       8084 non-null   object
#  5   Retweet-Count  8084 non-null   int64
#  6   Favorites      8084 non-null   int64
#  7   Created at     8084 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 505.4+ KB
# None

# %%
#We don't need the 2 columns called Unnamed, we're gonna drop them. Also, we will remove duplicated tweets. 
stimulus_raw.drop(columns=["Unnamed: 0", "Unnamed: 0.1"], axis=1, inplace=True)

# Drop duplicated rows
stimulus_raw.drop_duplicates(inplace=True)

# Created at column's type should be datatime
stimulus_raw["Created at"] = pd.to_datetime(stimulus_raw["Created at"])

# Print the info again
print(stimulus_raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7696 entries, 0 to 8083
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Content        7696 non-null   object
#  1   Location       5414 non-null   object
#  2   Username       7696 non-null   object
#  3   Retweet-Count  7696 non-null   int64
#  4   Favorites      7696 non-null   int64
#  5   Created at     7696 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 420.9+ KB
# None

# %%
# Now we clean up the content of the tweets. We'll remove stopwords, punctuation, mention, hashtag, links, and one-or-two letter words lik a or an
#After that, we'll tokenize the tweets
def clean_up(tweet):
    
    # Remove links
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    
    # Remove mentions and hashtag
    tweet = re.sub(r'\@\w+|\#','', tweet)
    
    # Tokenize the words
    tokenized = word_tokenize(tweet)

    # Remove the stop words
    tokenized = [token for token in tokenized if token not in stopwords.words("english")] 

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    tokenized = [lemmatizer.lemmatize(token, pos='a') for token in tokenized]

    # Remove non-alphabetic characters and keep the words contains three or more letters
    tokenized = [token for token in tokenized if token.isalpha() and len(token)>2]
    
    return tokenized
    
# Call the function and store the result into a new column
stimulus_raw["Processed"] = stimulus_raw["Content"].str.lower().apply(clean_up)


# Print the first fifteen rows of Processed
display(stimulus_raw[["Processed"]].head(15))
# Out:
#                                             Processed
# 0   [follow, bidenlies, bidenlied, bidenremorse, b...
# 1   [link, get, trump, fuckbiden, bidenlied, repub...
# 2   [trump, wapo, slam, bidenlied, georgia, electi...
# 3   [youtube, away, dislikes, whitehouse, social, ...
# 4   [everyone, knows, happening, protect, biden, a...
# 5   [kidsincages, good, kidsincages, racist, good,...
# 6   [kidsincages, good, kidsincages, racist, good,...
# 7   [never, seen, anyone, protect, person, like, b...
# 8   [tired, imposed, kids, school, sick, america, ...
# 9   [stopaapihate, abcnews, cnn, hannity, tuckerca...
# 10  [food, thoughts, stopaapihate, abcnews, cnn, h...
# 11  [food, thoughts, stopaapihate, abcnews, cnn, h...
# 12  [admitted, unpopular, president, ever, even, h...
# 13  [consent, vaccine, passport, iwillnotcomply, b...
# 14  [breaking, news, alert, bidenlied, bidenborder...
# 15  [agree, disagree, newsmedia, wwe, aew, news, b...
# 16  [really, amazing, portland, allegedly, honoure...
# 17  [putting, masks, patriotism, standing, infring...
# 18  [surrounded, liars, pinocchios, nowhere, near,...
# 19  [bidenlied, said, starting, scratch, fight, co...

# %%
#We record the length of the tweets and the number of words in each tweets in new columns
# Get the tweet lengths
stimulus_raw["Length"] = stimulus_raw["Content"].str.len()

# Get the number of words in tweets
stimulus_raw["Words"] = stimulus_raw["Content"].str.split().str.len()

# Display the new columns
display(stimulus_raw[["Length", "Words"]])
# Out:
#       Length  Words
# 0         79      8
# 1        255     24
# 2        119     14
# 3        278     27
# 4        280     37
# ...      ...    ...
# 8079     104     15
# 8080     155     22
# 8081     140     18
# 8082      52      6
# 8083      60      7
#
# [7696 rows x 2 columns]

# %%
#we want to record the locations of the tweet, so that maybe we can analyze how people from different regions feel about this stimulus check.
#we'll store the location of the tweet to a column. If there's no location found, we'll mark it as 'unknown'
stimulus_raw["Location"].fillna("unknown", inplace=True)

# Print the unique locations and number of unique locations
print("Unique Values:",stimulus_raw["Location"].unique())
print("Unique Value count:",len(stimulus_raw["Location"].unique()))
# Out:
# Unique Values: ['unknown' 'Etats-Unis' 'Hyères, France' ... 'PHL, PA' 'Kansas, USA'
#  'Tennessee']
# Unique Value count: 2043

# %%
# After recording the locations, we want to classify the locations that are states within the US versus foreign countries.
def get_countries(location):
    
    # If location is a country name return its alpha2 code
    if pycountry.countries.get(name= location):
        return pycountry.countries.get(name = location).alpha_2
    
    # If location is a subdivisions name return the countries alpha2 code
    try:
        pycountry.subdivisions.lookup(location)
        return pycountry.subdivisions.lookup(location).country_code
    except:
        # If the location is neither country nor subdivision return the "unknown" tag
        return "unknown"

# Call the function and store the country codes in the Country column
stimulus_raw["Country"] = stimulus_raw["Location"].apply(get_countries)

# Print the unique values
print(stimulus_raw["Country"].unique())

# Print the number of unique values
print("Number of unique values:",len(stimulus_raw["Country"].unique()))
# Out:
# ['unknown' 'US' 'GE' 'FR' 'CU' 'CA' 'EG' 'IE' 'HK' 'BS' 'LU' 'AU' 'IL'
#  'GB' 'SG' 'MY' 'NL' 'DZ' 'GT' 'NZ' 'AQ' 'ES' 'NG' 'JM' 'DE' 'LR' 'NI'
#  'JP' 'UG' 'DK' 'CR' 'UM']
# Number of unique values: 32

# %%
def get_states(location):
    
    # If location is a US state name return its alpha2 code
    if us.states.lookup(location):
        state = us.states.lookup(location)
        return state.abbr
    
    # If location is not a us state, return not-us or unknown
    try:
        pycountry.subdivisions.lookup(location)
        return "not-us"
    except:
        # If the location is neither country nor subdivision return the "unknown" tag
        return "unknown"

# Call the function and store the country codes in the Country column
stimulus_raw["States"] = stimulus_raw["Location"].apply(get_states)

# Print the unique values
print(stimulus_raw["States"].unique())

# Print the number of unique values
print("Number of unique values:",len(stimulus_raw["States"].unique()))
# Out:
# ['unknown' 'GA' 'OK' 'ME' 'CT' 'OH' 'not-us' 'TX' 'WI' 'AR' 'FL' 'MN' 'PA'
#  'IA' 'LA' 'NY' 'MI' 'IL' 'OR' 'NJ' 'KY' 'NH' 'SC' 'MA' 'KS' 'WV' 'CA'
#  'AL' 'IN' 'CO' 'NV' 'MO' 'VA' 'DE' 'NM' 'SD' 'AZ' 'HI' 'WA' 'MD' 'NC'
#  'DC' 'MS' 'VT' 'AK' 'TN']
# Number of unique values: 46

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-9faeec438618> in <module>
#       1 stimulus_raw.to_csv("stimulusProcessed.csv")
# ----> 2 display(stimulusProcessed.head())
#
# NameError: name 'stimulusProcessed' is not defined

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from gensim.models import Word2Vec

# %%
tfidf_stops = ["stimulus", "check", "stimulus check", "biden", "bidenlied"]


# Initialize a Tf-idf Vectorizer
vectorizer = TfidfVectorizer(max_features=8, stop_words= tfidf_stops)
m=stimulus_raw["Processed"].apply(lambda x: ' '.join(x))
tfidf_matrix = vectorizer.fit_transform(m)
display(tfidf_matrix)
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns= vectorizer.get_feature_names())
display(tfidf_df.head())
# Out:
# <7696x8 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6956 stored elements in Compressed Sparse Row format>
#    amp       get  lalate  lied  people  stimuluscheck     trump  tune
# 0  0.0  0.000000     0.0   0.0     0.0            0.0  0.000000   0.0
# 1  0.0  0.687136     0.0   0.0     0.0            0.0  0.726528   0.0
# 2  0.0  0.000000     0.0   0.0     0.0            0.0  1.000000   0.0
# 3  0.0  0.000000     0.0   0.0     0.0            0.0  0.000000   0.0
# 4  0.0  0.000000     0.0   0.0     0.0            0.0  0.000000   0.0

# %%
#Explore the data

# %%
# Print the minimum datetime
print("Since:",stimulus_raw["Created at"].min())

# Print the maximum datetime
print("Until",stimulus_raw["Created at"].max())
# Out:
# Since: 2021-03-23 03:40:38
# Until 2021-03-30 23:04:13

# %%
sns.set()

# Plot the histogram of hours
sns.distplot(stimulus_raw["Created at"].dt.hour, bins=24)
plt.title("Hourly Distribution of Tweets")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
countries = stimulus_raw[stimulus_raw.Country!='unknown']

# Select the top 20 countries
top_countries = countries["Country"].value_counts(sort=True).head(20)

# Convert alpha2 country codes to country names and store in a list
country_fullnames = []
for alpha2 in top_countries.index:
    country_fullnames.append(pycountry.countries.get(alpha_2=alpha2).name)

# Visualize the top 20 countries
plt.figure(figsize=(12,10))
sns.barplot(y=country_fullnames,x=top_countries, orient="h", palette="RdYlGn")
plt.xlabel("Tweet count")
plt.ylabel("Countries")
plt.title("Top 20 Countries")
plt.show()

# %%
states = stimulus_raw[stimulus_raw.States!='unknown']

# Select 50 states
top_states = states["States"].value_counts(sort=True).head(50)

# Convert alpha2 country codes to country names and store in a list
states_fullnames = []
for alpha2 in top_states.index:
    states_fullnames.append(us.states.lookup(alpha2))

# Visualize the top 20 countries
plt.figure(figsize=(12,10))
sns.barplot(y=states_fullnames,x=top_states, orient="h", palette="RdYlGn")
plt.xlabel("Tweet count")
plt.ylabel("States")
plt.title("Tweets by States")
plt.show()

# %%
# Display the most popular tweets
display(stimulus_raw.sort_values(by=["Favorites","Retweet-Count", ], axis=0, ascending=False)[["Content","Retweet-Count","Favorites"]].head(20))
# Out:
#                                                 Content  Retweet-Count  \
# 7552  Biden’s son lied about his drug use on his for...          10016
# 6746  Let me get this straight. Biden is being criti...           2904
# 8061  Also, don’t forget the part about the unoffici...            732
# 7616  Biden’s already bombed Syria &amp; refuses to ...            617
# 7291  Eric Trump says he'd be in jail for allegedly ...            427
# 6799  Buttiegieg LIES to CNN: “If you make less than...            318
# 7734  ICYMI, Hunter Biden lied twice on his 4473 to ...            738
# 7647  Left-wing fact checker, Politifact, says Biden...            354
# 6765  This is happening under @JoeBiden. This is hap...            215
# 7213  Biden lied about getting water in line when yo...            289
# 6165  BREAKING: Senate Democrats to include recurrin...            225
# 7409  @ChidiNwatu @GOPLeader McCarthy adores the for...            122
# 3329  Thursday Thoughts #bulldogs #dogsoftwitter #th...             55
# 7991  Pres Biden stood in front of America yesterday...            193
# 4465  A 4th stimulus check would be nice but lowkey ...             72
# 7794  I am not talking about a small minority\n\nWe ...             48
# 6693  Biden's foreign policy is just like Trump\n\nH...             87
# 7153  If I lied on my background check to illegally ...            194
# 7930  @benshapiro Trump lied tens of thousands of ti...              9
# 7907  Even the left wing fact checking sites say Bid...            103
#
#       Favorites
# 7552      47094
# 6746      15056
# 8061       2153
# 7616       2033
# 7291       2018
# 6799       1315
# 7734       1305
# 7647       1229
# 6765        799
# 7213        701
# 6165        656
# 7409        620
# 3329        576
# 7991        514
# 4465        447
# 7794        403
# 6693        361
# 7153        353
# 7930        336
# 7907        266

# %%
frequencies = pd.DataFrame(tfidf_matrix.sum(axis=0).T,index=vectorizer.get_feature_names(),columns=['total frequency'])

# Sort the words by frequency
frequencies.sort_values(by='total frequency',ascending=False, inplace=True)
# Display the most 20 frequent words
display(frequencies.head(20))
# Out:
#                total frequency
# lied               1137.808855
# stimuluscheck       989.360916
# get                 710.154473
# people              576.178436
# trump               544.923916
# amp                 541.674209
# lalate              427.391327
# tune                304.572147

# %%
#Sentiment Analysis

# %%
from textblob import TextBlob

# %%
m=stimulus_raw["Processed"].apply(lambda x: ' '.join(x))
stimulus_raw["Polarity"] = m.apply(lambda word: TextBlob(word).sentiment.polarity)
stimulus_raw["Subjectivity"] = m.apply(lambda word: TextBlob(word).sentiment.subjectivity)

# Display the Polarity and Subjectivity columns
display(stimulus_raw[["Polarity","Subjectivity"]].head(10))
# Out:
#    Polarity  Subjectivity
# 0  0.000000      0.000000
# 1  0.000000      0.000000
# 2  0.000000      0.000000
# 3  0.033333      0.066667
# 4  0.000000      0.000000
# 5  0.560417      0.650000
# 6  0.572500      0.580000
# 7  0.000000      0.100000
# 8 -0.371429      0.541270
# 9  0.000000      0.000000

# %%
def analyse_polarity(polarity):
    if polarity > 0:
        return "Positive"
    if polarity == 0:
        return "Neutral"
    if polarity < 0:
        return "Negative"

# Apply the funtion on Polarity column and add the results into a new column
stimulus_raw["Label"] = stimulus_raw["Polarity"].apply(analyse_polarity)

# Display the Polarity and Subjectivity Analysis
display(stimulus_raw[["Label"]].head(10))
# Out:
#       Label
# 0   Neutral
# 1   Neutral
# 2   Neutral
# 3  Positive
# 4   Neutral
# 5  Positive
# 6  Positive
# 7   Neutral
# 8  Negative
# 9   Neutral

# %%
print(stimulus_raw["Label"].value_counts())
# Out:
# Positive    3162
# Neutral     2533
# Negative    2001
# Name: Label, dtype: int64

# %%
stimulus_raw["Label"] = stimulus_raw["Label"].astype("category")

# Visualize the Label counts
sns.countplot(stimulus_raw["Label"])
plt.title("Label Counts")
plt.show()

# Visualize the Polarity scores
plt.figure(figsize = (10, 10)) 
sns.scatterplot(x="Polarity", y="Subjectivity", hue="Label", data=stimulus_raw)
plt.title("Subjectivity vs Polarity")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
display(stimulus_raw.sort_values(by=["Polarity","Favorites","Retweet-Count", ], axis=0, ascending=[False, False, False])[["Content","Retweet-Count","Favorites","Polarity"]].head(20))

# Display the negative tweets
display(stimulus_raw.sort_values(by=["Polarity", "Favorites", "Retweet-Count"], axis=0, ascending=[True, False, False])[["Content","Retweet-Count","Favorites","Polarity"]].head(20))
# Out:
#                                                 Content  Retweet-Count  \
# 2216  Excellent column by our Founder @rainforestboo...              2
# 2988  And because i am fed up of moronic liar #Biden...              0
# 7111  @JordanSchachtel My position is you are an air...              0
# 2211  What a wonderful front page of climate news we...              1
# 2778  #America also oozing a ton of  #methane\nPerfe...              0
# 4867  @pulte Well because you can sounds like a supe...              0
# 202   @FoxNews @tedcruz @POTUS  Biden's handlers twe...              0
# 2404  @JoeBiden the best #stimulus package is 0% inc...              0
# 157   Excellent Hashtag I say 💁🏻‍♀️ #PassitOn @SenTe...              1
# 3271  Got your #stimulus check? refund? What is the ...              1
# 203   @tedcruz @POTUS  Biden's handlers tweeted just...              0
# 530   Did you know the interrobang ‽ was invented in...              0
# 3463  WAR IS THE BEST #STIMULUS PROGRAM https://t.co...              0
# 3469  I got my stimulus check yesterday in the mail....              0
# 4408  Looking for ways to use your stimulus check? M...              0
# 4806  @MoChains @unlimitedcope @cyrii_MM COPEing up ...              0
# 5268  If we get this 4th stimulus check, I’m getting...              0
# 6550  @Book_Gobbler @RegardingComic You're welcome! ...              0
# 7987  @jjgomez_7 The comments are priceless lol 😂 \n...              0
# 41    @disclosetv And yet you don’t need an ID to vo...              0
#
#       Favorites  Polarity
# 2216          6       1.0
# 2988          5       1.0
# 7111          4       1.0
# 2211          3       1.0
# 2778          3       1.0
# 4867          2       1.0
# 202           1       1.0
# 2404          1       1.0
# 157           0       1.0
# 3271          0       1.0
# 203           0       1.0
# 530           0       1.0
# 3463          0       1.0
# 3469          0       1.0
# 4408          0       1.0
# 4806          0       1.0
# 5268          0       1.0
# 6550          1       0.9
# 7987          1       0.9
# 41            0       0.9
#                                                 Content  Retweet-Count  \
# 124   @TimRunsHisMouth The shepherd doesn't lie to t...              1
# 674   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              1
# 3582  Blow up this ass holes Twitter. Disgusting! #s...              0
# 653   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              0
# 754   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              0
# 759   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              0
# 809   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              0
# 4215  Terrible idea\n\nShould push job creation. Eli...              0
# 163   SHOCKING!! #BorderCrisis #ShameOnBiden For Loc...              1
# 186   We ARE enslaved by biden and his outrageous ta...              1
# 497   Absolutely terrifying. #BidenHarrisAdministrat...              1
# 702   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              1
# 726   THE SHOCKING VIDEO (@ 20 MINUTE MARK)!\n\nNOW ...              0
# 5320  The complaining about Uber/Lyft drivers taking...              0
# 5865  @luckyginnie3 This is beyond pathetic and he i...              0
# 6992  @rroliver360 @CTVNews Something Biden also lie...              0
# 5059  @SenSanders Yes!!! It's absolutely awful 😩...a...              0
# 5755  Omo my response was a fiery tongue, trust God ...              0
# 6112  STIMULUS UPDATE 3/30 TUES\n\nIRS reported that...              0
# 6761  @Braylesong @JackPosobiec The hypocrisy is Joe...              0
#
#       Favorites  Polarity
# 124           8      -1.0
# 674           6      -1.0
# 3582          3      -1.0
# 653           2      -1.0
# 754           2      -1.0
# 759           2      -1.0
# 809           2      -1.0
# 4215          2      -1.0
# 163           1      -1.0
# 186           1      -1.0
# 497           1      -1.0
# 702           1      -1.0
# 726           1      -1.0
# 5320          1      -1.0
# 5865          1      -1.0
# 6992          1      -1.0
# 5059          0      -1.0
# 5755          0      -1.0
# 6112          0      -1.0
# 6761          0      -1.0

# %%
positives_by_state = stimulus_raw[(stimulus_raw.States!='not-us')&(stimulus_raw.States!='unknown')].groupby("Label")["States"].value_counts().Negative.sort_values(ascending=False)
negatives_by_state =stimulus_raw[(stimulus_raw.States!='not-us')&(stimulus_raw.States!='unknown')].groupby("Label")["States"].value_counts().Positive.sort_values(ascending=False)

# Print them out
print("Positive \n")
print(positives_by_state)
print("\nNegative\n")
print(negatives_by_state)

# Create a mask for top 1 countries (by tweets count)
mask = stimulus_raw["States"].isin(top_states.index[:10]).values

# Create a new DataFrame only includes top10 country
top_20df = stimulus_raw.iloc[mask,:]

# Visualize the top 10 countries
plt.figure(figsize=(12,10))
sns.countplot(x="States", hue="Label", data=top_20df, order=top_20df["States"].value_counts().index)
plt.xlabel("States")
locs, labels = plt.xticks()
plt.xticks(locs, states_fullnames[:10])
plt.xticks(rotation=45)
plt.ylabel("Tweet count")
plt.title("Top 10 States")
plt.show()
# Out:
# Positive
#
# States
# NY    8
# CA    6
# MI    6
# TX    6
# FL    5
# GA    4
# LA    4
# CT    3
# IA    3
# MN    3
# MA    2
# AL    2
# AZ    2
# KS    2
# OH    2
# PA    2
# SC    2
# VT    2
# WA    1
# AK    1
# AR    1
# HI    1
# IN    1
# MD    1
# NH    1
# OK    1
# OR    1
# SD    1
# WI    1
# Name: States, dtype: int64
#
# Negative
#
# States
# NY    15
# FL    11
# TX     8
# KY     7
# MI     7
# GA     5
# NJ     5
# OH     5
# CA     4
# ME     4
# IL     3
# OR     3
# CT     2
# AL     2
# CO     2
# DE     2
# KS     2
# MA     2
# NM     2
# OK     2
# WA     2
# WV     2
# TN     1
# AZ     1
# DC     1
# IA     1
# LA     1
# MS     1
# NC     1
# NV     1
# SC     1
# VA     1
# Name: States, dtype: int64

# %%
positive = stimulus_raw.loc[stimulus_raw.Label=="Positive"]["Created at"].dt.hour
negative = stimulus_raw.loc[stimulus_raw.Label=="Negative"]["Created at"].dt.hour

plt.hist(positive, alpha=0.5, bins=24, label="Positive", density=True)
plt.hist(negative, alpha=0.5, bins=24, label="Negative", density=True)
plt.xlabel("Hour")
plt.ylabel("PDF")
plt.title("Hourly Distribution of Tweets")
plt.legend(loc='upper right')
plt.show()

# %%
# It seems like there's no coordination bwt Polarity and hour of tweets

# %%
stimulus_raw.to_csv("stimulus_sentiments.csv")

# %%
stimulus_sentiment = pd.read_csv("stimulus_sentiments.csv")
display(stimulus_sentiment.head())
# Out:
#    Unnamed: 0                                            Content  \
# 0           0  @ZupancicJareen Follow #BidenLies #BidenLied a...
# 1           1  Link to get :👇👇👇\nhttps://t.co/kRoIosUS6y\n#Tr...
# 2           2  #Trump 🇺🇸\nWaPo Fact-Checkers Slam #BidenLied ...
# 3           3  YouTube doing away with dislikes bc of Whiteho...
# 4           4  Everyone knows this is happening to protect #B...
#
#            Location         Username  Retweet-Count  Favorites  \
# 0           unknown    Trish22758076              0          0
# 1        Etats-Unis   Hicham21940587              1          0
# 2    Hyères, France           C_W_UK              0          0
# 3  Clown World, USA  BEcAMearekonING              0          0
# 4           unknown       BilukCyril              0          0
#
#             Created at                                          Processed  \
# 0  2021-03-30 22:59:04  ['follow', 'bidenlies', 'bidenlied', 'bidenrem...
# 1  2021-03-30 22:48:48  ['link', 'get', 'trump', 'fuckbiden', 'bidenli...
# 2  2021-03-30 22:47:54  ['trump', 'wapo', 'slam', 'bidenlied', 'georgi...
# 3  2021-03-30 22:46:12  ['youtube', 'away', 'dislikes', 'whitehouse', ...
# 4  2021-03-30 22:39:17  ['everyone', 'knows', 'happening', 'protect', ...
#
#    Length  Words  Country   States  Polarity  Subjectivity     Label
# 0      79      8  unknown  unknown  0.000000      0.000000   Neutral
# 1     255     24  unknown  unknown  0.000000      0.000000   Neutral
# 2     119     14  unknown  unknown  0.000000      0.000000   Neutral
# 3     278     27  unknown  unknown  0.033333      0.066667  Positive
# 4     280     37  unknown  unknown  0.000000      0.000000   Neutral

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score

# %%
le = LabelEncoder()
stimulus_raw["Label_enc"] = le.fit_transform(stimulus_raw["Label"])

# Display the encoded labels
display(stimulus_raw[["Label_enc"]].head())

# Select the features and the target
X = stimulus_raw['Processed']
y = stimulus_raw["Label_enc"]
# Out:
#    Label_enc
# 0          1
# 1          1
# 2          1
# 3          2
# 4          1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=34, stratify=y)

# %%
model_vectorizer = TfidfVectorizer()

x_train=X_train.apply(lambda x: ' '.join(x))

x_test=X_test.apply(lambda x: ' '.join(x))

# First fit the vectorizer with our training set
tfidf_train = vectorizer.fit_transform(x_train)

# Now we can fit our test data with the same vectorizer
tfidf_test = vectorizer.transform(x_test)

# Initialize the Bernoulli Naive Bayes classifier
nb = BernoulliNB()

# Fit the model
nb.fit(tfidf_train, y_train)

# Print the accuracy score
best_accuracy = cross_val_score(nb, tfidf_test, y_test, cv=10, scoring='accuracy').max()
print("Accuracy:",best_accuracy)
# Out:
# Accuracy: 0.487012987012987

# %%
# Predict the labels
y_pred = nb.predict(tfidf_test)

# Print the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix\n")
print(cm)

# Print the Classification Report
cr = classification_report(y_test, y_pred)
print("\n\nClassification Report\n")
print(cr)
# Out:
# Confusion Matrix
#
# [[155 144 101]
#  [108 252 147]
#  [134 274 225]]
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.39      0.39      0.39       400
#            1       0.38      0.50      0.43       507
#            2       0.48      0.36      0.41       633
#
#     accuracy                           0.41      1540
#    macro avg       0.41      0.41      0.41      1540
# weighted avg       0.42      0.41      0.41      1540

# %%
# Save the model
pickle.dump(nb, open("stimulus_model.pkl", 'wb'))
